# %% [markdown]
# <a href="https://colab.research.google.com/github/nishan2001/ML-From-Scratch/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
#
# ### Data Preprocessing in ML using pandas
# -📚 Data pprocessing is reuiredd tasks for cleaning the data and making it suitable for a ML model which also increase the accuracy and efficiency of ML model
#
# -✨ Pandas is an open soorcePython package that is most widely used for data science/data analysis and machine learning tasks.It is built on top of another package named NumPy , which provides spport for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transfom them into a standard and normalized format.
#
# 🎯 Preprocessing involves the following aspects
#
#     - misssing values
#     - data standardization
#     - data normalization
#     - data mining

# %%
import pandas as pd

# %%
data = {
    "cars": ["bmw", "honda", "suzuki", "ferrari"],
    "models": ["2007", "2009", "2010", "2016"],
    "passenger": ["5", "6", "7", "2"]
}
print(data)
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'ferrari'], 'models': ['2007', '2009', '2010', '2016'], 'passenger': ['5', '6', '7', '2']}

# %%
data = {
    "cars": ["bmw", "honda", "suzuki", "ferrari"],
    "models": ["2007", "2009", "2010", "2016"],
    "passenger": ["5", "6", "7", "2"]
}
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'ferrari'],
#  'models': ['2007', '2009', '2010', '2016'],
#  'passenger': ['5', '6', '7', '2']}

# %%
# convert the data into dataframe
df  = pd.DataFrame(data)
df
# Out:
#       cars models passenger
# 0      bmw   2007         5
# 1    honda   2009         6
# 2   suzuki   2010         7
# 3  ferrari   2016         2

# %%
# save the file as a csv(comma separated vale) file
df.to_csv("/content/drive/MyDrive/MAchine Learning/cars_data.csv")

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
# Pandas series
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#create labels in pandas with index
a = [1, 7, 2]
myvar = pd.Series(a, index=["x", "y", "z"])
print(myvar)
#myvar
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
# how to acces the series
print(myvar["x"])
# Out:
# 1

# %%
# task : create a dataframe named df with data calores and duration
import pandas as pd
data = {
    "calories": ["500", "400", "350"],
    "duration": ["7", "8", "9"]
}
a = pd.DataFrame(data)
print(a)
# Out:
#   calories duration
# 0      500        7
# 1      400        8
# 2      350        9

# %%
print(a.loc[1])
# Out:
# calories    400
# duration      8
# Name: 1, dtype: object

# %%
print(a.loc[[1,2]])
# Out:
#   calories duration
# 1      400        8
# 2      350        9

# %%
import pandas as pd
data = {
    "calories": [500, 400, 350],
    "duration": [7 , 8, 9]
}
df = pd.DataFrame(data, index= ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       500         7
# day2       400         8
# day3       350         9

# %%
print(df.loc["day2"])
# Out:
# calories    400
# duration      8
# Name: day2, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df.head(8)
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01'    110       130     409.1
# 1        60  2020/12/02'    117       145     479.0
# 2        60  2020/12/03'    103       135     340.0
# 3        45  2020/12/04'    109       175     282.4
# 4        45  2020/12/05'    117       148     406.0
# 5        60  2020/12/06'    102       127     300.0
# 6        60  2020/12/07'    110       136     374.0
# 7       450  2020/12/08'    104       134     253.3

# %%
df.tail(6)
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 26        60   12/26/2020    100       120     250.0
# 27        60  2020/12/27'     92       118     241.0
# 28        60  2020/12/28'    103       132       NaN
# 29        60  2020/12/29'    100       132     280.0
# 30        60  2020/12/30'    102       129     380.3
# 31        60  2020/12/31'     92       115     243.0

# %%
#lets see the shape of the dataset
#total rows and columns
df.shape
# Out:
# (32, 5)

# %%
#examine the data type
data_types = df.dtypes
data_types
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
#identify null values variables
isnull=df.isnull()
isnull
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
isnull_count = isnull.sum()
print("Total no of null vales:",isnull_count)
# Out:
# Total no of null vales: Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
#total nulls in dataset
total_isnull_count = isnull.sum().sum()
print("Total nulls:", total_isnull_count)
# Out:
# Total nulls: 3

# %%
#replace single quote with blank and make the date formatted
df["Date"] = df["Date"].replace("'","", regex = True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
# handle null vales, return data frame with no empty cells
# we can use df.dropna(), it removes empty cell but will not change the ddataframe
#if we want dataframe to be changed, simply use inplace=Truene
new_df = df.dropna()
new_df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
isnull_count_newdf = new_df.isnull()
isnull_count_newdf
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 19     False  False  False     False     False
# ...

# %%
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
# another way of handling the null values is by relacing the null values
df.fillna(130, inplace = True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df = pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")
df["Calories"].fillna(130, inplace = True)
df
# Out:
# <ipython-input-32-7f356c3aad58>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(130, inplace = True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# ...

# %%
# fill specific with mean, median and mode
df = pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")
x = df["Calories"].mean()
df["Calories"].fillna(x, inplace =True)
df
# Out:
# <ipython-input-33-1f60aaa43e54>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(x, inplace =True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130    409.10
# 1         60  2020/12/02'    117       145    479.00
# 2         60  2020/12/03'    103       135    340.00
# 3         45  2020/12/04'    109       175    282.40
# 4         45  2020/12/05'    117       148    406.00
# 5         60  2020/12/06'    102       127    300.00
# ...
